# %%
import logging
import sys

from neo4j import GraphDatabase

class App:
    
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        # Don't forget to close the driver connection when you are finished with it
        self.driver.close()

    @staticmethod
    def enable_log(level, output_stream):
        handler = logging.StreamHandler(output_stream)
        handler.setLevel(level)
        logging.getLogger("neo4j").addHandler(handler)
        logging.getLogger("neo4j").setLevel(level)
        
        
    ###############
    #Creating nodes
    @staticmethod
    def _load_atmosphere(tx):
        print("Loading atmosphere...")
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///atmosphere.csv' AS row "
            "CREATE (:Atmosphere {id: row.atmosphere_id, tag: row.atmospehere_tag});"
            )
        tx.run(query)
        print("Atmosphere loaded")

    @staticmethod
    def _load_food(tx):
        print("Loading food...")
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///food.csv' AS row "
            "CREATE (:Food {id: row.tag_id, food: row.food});"
            )
        tx.run(query)
        print("Food loaded")

    @staticmethod
    def _load_type_cuisine(tx):
        print("Loading type of cuisine...")
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///type_cuisine.csv' AS row "
            "CREATE (:Cuisine {id: row.cuisine_id, cuisine: row.cuisine});"
            )
        tx.run(query)
        print("Cuisine loaded")

    @staticmethod
    def _load_users(tx):
        print("Loading users...")
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///users.csv' AS row "
            "CREATE (:User {id: row.reviewerId});"
            )
        tx.run(query)
        print("Users loaded")

    @staticmethod
    def _load_establishments(tx):
        print("Loading Establishments...")
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///establishments.csv' AS row "
            "CREATE (:Establishment {id: row.merge_id, name: row.biz_name});"
            )
        tx.run(query)
        print("Establishments loaded")

  
        
    ###############
    #Function to load all nodes
    def load_nodes(self):
        with self.driver.session() as session:
            session.write_transaction(self._load_atmosphere)

        with self.driver.session() as session:
            session.write_transaction(self._load_food)

        with self.driver.session() as session:
            session.write_transaction(self._load_type_cuisine)

        with self.driver.session() as session:
            session.write_transaction(self._load_users)

        with self.driver.session() as session:
            session.write_transaction(self._load_establishments)

       
    ###############
    #Creating indexes on Ids
    @staticmethod
    def _create_index_atmosphereid(tx):
        print("Creating index on Atmosphere.id...")
        query = ("CREATE INDEX atmosphereid_index FOR (n:Atmosphere) ON (n.id)")
        tx.run(query)
        print("Created index on Atmosphere.id")
    
    @staticmethod
    def _create_index_foodid(tx):
        print("Creating index on Food.id...")
        query = ("CREATE INDEX foodid_index FOR (n:Food) ON (n.id)")
        tx.run(query)
        print("Created index on Food.id")

    @staticmethod
    def _create_index_cuisineid(tx):
        print("Creating index on Cuisine.id...")
        query = ("CREATE INDEX cuisineid_index FOR (n:Cuisine) ON (n.id)")
        tx.run(query)
        print("Created index on Cuisine.id")

    @staticmethod
    def _create_index_userid(tx):
        print("Creating index on User.id...")
        query = ("CREATE INDEX userid_index FOR (n:User) ON (n.id)")
        tx.run(query)
        print("Created index on User.id")

    @staticmethod
    def _create_index_establishmentid(tx):
        print("Creating index on Establishment.id...")
        query = ("CREATE INDEX establishmentid_index FOR (n:Establishment) ON (n.id)")
        tx.run(query)
        print("Created index on Establishment.id")

        

    ###############
    #Function to create indexes
    def create_indexes(self):
        with self.driver.session() as session:
            session.write_transaction(self._create_index_atmosphereid)
        
        with self.driver.session() as session:
            session.write_transaction(self._create_index_foodid)

        with self.driver.session() as session:
            session.write_transaction(self._create_index_cuisineid)

        with self.driver.session() as session:
            session.write_transaction(self._create_index_userid)

        with self.driver.session() as session:
            session.write_transaction(self._create_index_establishmentid)

            
        
    ###############
    #Creating edges
    @staticmethod
    def establishment_has_atmosphere(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///establishment_has_atmosphere.csv' AS row "
            "MATCH (e:Establishment {id: row.merge_id}), (a:Atmosphere {id: row.atmosphere_id})"
            "CREATE (e)-[r:has]->(a)"
            )
        tx.run(query)
        print("Edge (establishment)-[Has]->(atmosphere) loaded")
    
    @staticmethod
    def _establishment_has_cuisine(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///establishment_has_cuisine.csv' AS row "
            "MATCH (e:Establishment {id: row.merge_id}), (c:Cuisine {id: row.cuisine_id})"
            "CREATE (e)-[r:has]->(c)"
            )
        tx.run(query)
        print("Edge (establishment)-[Has]->(cuisine) loaded")


    @staticmethod
    def _establishment_offeres_food(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///establishment_offers_food.csv' AS row "
            "MATCH (e:Establishment {id: row.merge_id}), (f:Food {id: row.tag_id})"
            "CREATE (e)-[r:offers]->(f)"
            )
        tx.run(query)
        print("Edge (establishment)-[Offers]->(food) loaded")


    @staticmethod
    def _user_isFriend_with(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///user_isFriendsWith.csv' AS row "
            "MATCH (u1:User {id: row.friend1}), (u2:User {id: row.friend2})"
            "CREATE (u1)-[:isFriendWith]->(u1);"
            )
        tx.run(query)
        print("Edge (user)-[isFriendsWith]->(user) loaded")
        

    @staticmethod
    def _user_likes_establishment(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///user_likes_establishment.csv' AS row "
            "MATCH (u:User {id: row.reviewerId}),(e:Establishment {id: row.merge_id})"
            "CREATE (u)-[:likes]->(e);"
            )
        tx.run(query)
        print("Edge (user)-[likes]->(establishment) loaded")
        

    @staticmethod
    def _user_likes_food(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///user_likes_food.csv' AS row "
            "MATCH (u:User {id: row.reviewerId}),(f:Food {id: row.tag_id})"
            "CREATE (u)-[:likes]->(f);"
            )
        tx.run(query)
        print("Edge (user)-[likes]->(food) loaded")
        
 
    @staticmethod
    def _user_prefers_atmosphere(tx):
        query = (
            "LOAD CSV WITH HEADERS FROM 'file:///user_prefers_atmosphere.csv' AS row "
            "MATCH (u:User {id: row.reviewerId}),(a:Atmosphere {id: row.atmosphere_id})"
            "CREATE (u)-[r:prefers]->(a)"
            "SET r.tag = row.tags;"
            )
        tx.run(query)
        print("Edge (user)-[prefers]->(atmosphere) loaded")


        

    ###############
    #Function to load all edges
    def load_edges(self):
        with self.driver.session() as session:
            session.write_transaction(self.establishment_has_atmosphere)
        
        with self.driver.session() as session:
            session.write_transaction(self._establishment_has_cuisine)

        with self.driver.session() as session:
            session.write_transaction(self._establishment_offeres_food)

        with self.driver.session() as session:
            session.write_transaction(self._user_isFriend_with)

        with self.driver.session() as session:
            session.write_transaction(self._user_likes_establishment)

        with self.driver.session() as session:
            session.write_transaction(self._user_likes_food)

        with self.driver.session() as session:
            session.write_transaction(self._user_prefers_atmosphere)

            

if __name__ == "__main__":
    bolt_url = "neo4j://localhost:7687"
    user = "neo4j"
    password = "sdm123"
    App.enable_log(logging.INFO, sys.stdout)
    app = App(bolt_url, user, password)
    app.load_nodes()
    app.create_indexes()
    app.load_edges()
    app.close()
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# /var/folders/r_/f6d_zpkj3g5b5cxk43mjw7cc0000gn/T/ipykernel_10770/2372797275.py in <module>
#     266     App.enable_log(logging.INFO, sys.stdout)
#     267     app = App(bolt_url, user, password)
# --> 268     app.load_nodes()
#     269     app.create_indexes()
#     270     app.load_edges()
#
# /var/folders/r_/f6d_zpkj3g5b5cxk43mjw7cc0000gn/T/ipykernel_10770/2372797275.py in load_nodes(self)
#      79     def load_nodes(self):
#      80         with self.driver.session() as session:
# ---> 81             session.write_transaction(self._load_atmosphere)
#      82
#      83         with self.driver.session() as session:
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/work/simple.py in write_transaction(self, transaction_function, *args, **kwargs)
#     419         :return: a result as returned by the given unit of work
#     420         """
# --> 421         return self._run_transaction(WRITE_ACCESS, transaction_function, *args, **kwargs)
#     422
#     423
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/work/simple.py in _run_transaction(self, access_mode, transaction_function, *args, **kwargs)
#     320         while True:
#     321             try:
# --> 322                 self._open_transaction(access_mode=access_mode, metadata=metadata, timeout=timeout)
#     323                 tx = self._transaction
#     324                 try:
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/work/simple.py in _open_transaction(self, access_mode, metadata, timeout)
#     253     def _open_transaction(self, *, access_mode, metadata=None,
#     254                           timeout=None):
# --> 255         self._connect(access_mode=access_mode)
#     256         self._transaction = Transaction(
#     257             self._connection, self._config.fetch_size,
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/work/simple.py in _connect(self, access_mode)
#     106         if access_mode is None:
#     107             access_mode = self._config.default_access_mode
# --> 108         super()._connect(access_mode)
#     109
#     110     def _collect_bookmark(self, bookmark):
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/work/__init__.py in _connect(self, access_mode)
#      75                     imp_user=self._config.impersonated_user,
#      76                     bookmarks=self._bookmarks,
# ---> 77                     database_callback=self._set_cached_database
#      78                 )
#      79         self._connection = self._pool.acquire(
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in update_routing_table(self, database, imp_user, bookmarks, database_callback)
#    1070                         self.first_initial_routing_address, database=database,
#    1071                         imp_user=imp_user, bookmarks=bookmarks,
# -> 1072                         database_callback=database_callback
#    1073                 ):
#    1074                     # Why is only the first initial routing address used?
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in _update_routing_table_from(self, database, imp_user, bookmarks, database_callback, *routers)
#    1022                     address=address,
#    1023                     timeout=self.pool_config.connection_timeout,
# -> 1024                     database=database, imp_user=imp_user, bookmarks=bookmarks
#    1025                 )
#    1026                 if new_routing_table is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in fetch_routing_table(self, address, timeout, database, imp_user, bookmarks)
#     967         try:
#     968             new_routing_info = self.fetch_routing_info(
# --> 969                 address, database, imp_user, bookmarks, timeout
#     970             )
#     971         except Neo4jError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in fetch_routing_info(self, address, database, imp_user, bookmarks, timeout)
#     937             routing, or if routing support is broken or outdated
#     938         """
# --> 939         cx = self._acquire(address, timeout)
#     940         try:
#     941             routing_table = cx.route(
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in _acquire(self, address, timeout)
#     685                                   time_remaining())
#     686                     try:
# --> 687                         connection = self.opener(address, timeout)
#     688                     except ServiceUnavailable:
#     689                         self.remove(address)
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in opener(addr, timeout)
#     859         def opener(addr, timeout):
#     860             return Bolt.open(addr, auth=auth, timeout=timeout,
# --> 861                              routing_context=routing_context, **pool_config)
#     862
#     863         pool = cls(opener, pool_config, workspace_config, address)
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     356
#     357         try:
# --> 358             connection.hello()
#     359         except Exception:
#     360             connection.close()
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/_bolt4.py in hello(self)
#     441                                            on_success=on_success))
#     442         self.send_all()
# --> 443         self.fetch_all()
#     444         check_supported_server_product(self.server_info.agent)
#     445
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/__init__.py in fetch_all(self)
#     533             response = self.responses[0]
#     534             while not response.complete:
# --> 535                 detail_delta, summary_delta = self.fetch_message()
#     536                 detail_count += detail_delta
#     537                 summary_count += summary_delta
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/_bolt4.py in fetch_message(self)
#     307             self._server_state_manager.state = ServerStates.FAILED
#     308             try:
# --> 309                 response.on_failure(summary_metadata or {})
#     310             except (ServiceUnavailable, DatabaseUnavailable):
#     311                 if self.pool:
#
# ~/anaconda3/lib/python3.7/site-packages/neo4j/io/_common.py in on_failure(self, metadata)
#     244         code = metadata.get("code")
#     245         if code == "Neo.ClientError.Security.Unauthorized":
# --> 246             raise Neo4jError.hydrate(**metadata)
#     247         else:
#     248             raise ServiceUnavailable(
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
